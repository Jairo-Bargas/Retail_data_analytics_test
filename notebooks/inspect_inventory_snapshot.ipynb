# %%
import pandas as pd

# %%
tb_in = pd.read_csv('../data/raw/inventory_snapshot.csv')
tb_in.head()
# Out:
#   snapshot_date  product_id  store_id  stock_qty
# 0    2023-01-31           1         1         13
# 1    2023-01-31           1         2         12
# 2    2023-01-31           1         3         13
# 3    2023-01-31           1         4         16
# 4    2023-01-31           2         1         11

# %%
tb_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24000 entries, 0 to 23999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   snapshot_date  24000 non-null  object
#  1   product_id     24000 non-null  int64
#  2   store_id       24000 non-null  int64
#  3   stock_qty      24000 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 750.1+ KB

# %%
tb_in['snapshot_date'].duplicated().sum()
# Out:
# np.int64(23976)

# %%
tb_in['snapshot_date'].value_counts()
# Out:
# snapshot_date
# 2023-01-31    1000
# 2023-02-28    1000
# 2023-03-31    1000
# 2023-04-30    1000
# 2023-05-31    1000
# 2023-06-30    1000
# 2023-07-31    1000
# 2023-08-31    1000
# 2023-09-30    1000
# 2023-10-31    1000
# 2023-11-30    1000
# 2023-12-31    1000
# 2024-01-31    1000
# 2024-02-29    1000
# 2024-03-31    1000
# 2024-04-30    1000
# 2024-05-31    1000
# 2024-06-30    1000
# 2024-07-31    1000
# 2024-08-31    1000
# 2024-09-30    1000
# 2024-10-31    1000
# 2024-11-30    1000
# 2024-12-31    1000
# Name: count, dtype: int64

# %%
tb_in.duplicated(subset=['snapshot_date','product_id','store_id']).sum()
# Out:
# np.int64(0)

# %%
(tb_in['stock_qty']<= 0).sum()
# Out:
# np.int64(45)

# %%
tb_in[tb_in['stock_qty']<=0]
# Out:
#       snapshot_date  product_id  store_id  stock_qty
# 16       2023-01-31           5         1          0
# 96       2023-01-31          25         1          0
# 109      2023-01-31          28         2          0
# 2167     2023-03-31          42         4          0
# 2171     2023-03-31          43         4          0
# 3136     2023-04-30          35         1          0
# 3167     2023-04-30          42         4          0
# 3216     2023-04-30          55         1          0
# 4040     2023-05-31          11         1          0
# 4166     2023-05-31          42         3          0
# 5101     2023-06-30          26         2          0
# 5187     2023-06-30          47         4          0
# 5234     2023-06-30          59         3          0
# 6015     2023-07-31           4         4          0
# 6035     2023-07-31           9         4          0
# 6090     2023-07-31          23         3          0
# 7094     2023-08-31          24         3          0
# ...

# %% [markdown]
# ### Observaciones
#
# - Se debe modificar el snapshot_date a formato fecha.
